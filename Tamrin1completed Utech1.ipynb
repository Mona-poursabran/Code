# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# %%
x1 = np.random.rand(5)* 10
y1 = 2.358 * x1 -3
y1 = y1 + np.random.normal(scale = 0.1 , size = y1.shape)

x1 = x1.reshape(-1, 1)
y1 = y1.reshape(-1, 1)
#plt.plot(x1, y1 , 'bo')

# %%
model_1 = LinearRegression(normalize=True).fit(x1 , y1)
x1_line= np.arange(0, 10, 0.1).reshape(-1, 1)
y1_line = model_1.predict(x1_line)
plt.plot(x1, y1 , 'bo')
plt.plot(x1_line, y1_line)
score1_1 = model_1.score(x1 , y1)
print(score1_1)
# Out:
# 0.9999713076461629

# %%
poly1 = PolynomialFeatures(degree=4 ,include_bias=False)
x1_4 = poly1.fit_transform(x1)

poly1 = PolynomialFeatures(degree=16 , include_bias=False)
x1_16 = poly1.fit_transform(x1)

# %%
model_1_4 = LinearRegression().fit(x1_4, y1)

x1_line = np.arange(0, 10, 0.1).reshape(-1 , 1)
x1_line_4 = PolynomialFeatures(degree=4 , include_bias= False).fit_transform(x1_line)
y1_line_4 = model_1_4.predict(x1_line_4)

plt.plot(x1, y1, 'bo')
plt.plot(x1_line, y1_line_4 )

score1_4 = model_1_4.score(x1_4, y1)
print(score1_4)
# Out:
# 1.0

# %%
model_1_16 = LinearRegression().fit(x1_16, y1)

x1_line = np.arange(0,10 ,0.01).reshape(-1 , 1)
x1_line_16 = PolynomialFeatures(degree=16 , include_bias=False).fit_transform(x1_line)
y1_line_16 = model_1_16.predict(x1_line_16)

plt.plot(x1, y1, 'bo')
plt.plot(x1_line, y1_line_16 )

score1_16 = model_1_16.score(x1_16, y1)
print(score1_16)
# Out:
# 0.9999999999999977

# %%
x2 = np.random.rand(25) * 10
y2 = 3 * x2 - 1
y2 = y2 + np.random.normal( scale =0.5 , size = y2.shape)

x2 = x2.reshape(-1, 1)
y2 = y2.reshape(-1 , 1)
#plt.plot(x2, y2, 'co')

# %%
model_2 = LinearRegression(normalize= True).fit(x2 , y2)

x2_line = np.arange(0, 12, 0.01).reshape(-1, 1)
y2_line = model_2.predict(x2_line)

plt.plot(x2_line , y2_line)
plt.plot(x2, y2, 'co')

score2_1= model_2.score(x2 , y2)
print(score2_1)
# Out:
# 0.9980277435350207

# %%
poly2 = PolynomialFeatures(degree=4, include_bias=False)
x2_4 = poly2.fit_transform(x2)

poly2 = PolynomialFeatures(degree=16,include_bias=False)
x2_16 = poly2.fit_transform(x2)

# %%
model_2 = LinearRegression(normalize= True).fit(x2_4 , y2)

x2_line = np.arange(0, 12, 0.01).reshape(-1, 1)
x2_line_4 = PolynomialFeatures(degree=4, include_bias=False).fit_transform(x2_line)
y2_line_4= model_2.predict(x2_line_4)

plt.plot(x2_line , y2_line_4)
plt.plot(x2 , y2 , 'co')

score2_4 = model_2.score(x2_4 , y2)
print(score2_4)
# Out:
# 0.9982854228326472

# %%
model_2 = LinearRegression(normalize= True).fit(x2_16 , y2)

x2_line = np.arange(0, 10, 0.001).reshape(-1, 1)
x2_line_16 = PolynomialFeatures(degree=16,include_bias=False).fit_transform(x2_line)
y2_line_16= model_2.predict(x2_line_16)

plt.plot(x2_line , y2_line_16)
plt.plot(x2 , y2 , 'co')

score2_16 = model_2.score(x2_16 , y2)
print(score2_16)
# Out:
# 0.999665061357752

# %%
x3 = np.random.rand(100) * 20
y3 = 2.358 * x3 - 3.121
y3 = y3 + np.random.normal( scale =3 , size = y3.shape)
x3 = x3.reshape(-1 , 1)
y3 = y3.reshape (-1 , 1)
#plt.plot(x3, y3, 'mo')

# %%
model_3 = LinearRegression(normalize=True).fit(x3, y3)

x3_line = np.arange(-2, 25, 0.1).reshape(-1 , 1)
y3_line = model_3.predict(x3_line)

plt.plot(x3_line , y3_line)
plt.plot(x3, y3, 'mo')

score3_1 = model_3.score(x3 , y3)
print(score3_1)
# Out:
# 0.9587365998867599

# %%
poly3 = PolynomialFeatures(degree=4, include_bias=False)
x3_4 = poly3.fit_transform(x3)

poly3 = PolynomialFeatures(degree=16, include_bias=False)
x3_16 = poly3.fit_transform(x3)

# %%
model_3 = LinearRegression(normalize=True).fit(x3_4 , y3)

x3_line = np.arange(-2, 25, 0.1).reshape(-1 , 1)
x3_line_4 = PolynomialFeatures(degree=4, include_bias=False).fit_transform(x3_line)
y3_line_4 = model_3.predict(x3_line_4)

plt.plot(x3_line, y3_line_4)
plt.plot(x3 , y3, 'mo')

score3_4 = model_3.score(x3_4 , y3)
print(score3_4)
# Out:
# 0.9591516292471898

# %%
model_3 = LinearRegression(normalize=True).fit(x3_16 , y3)

x3_line = np.arange(0, 20, 0.001).reshape(-1 , 1)
x3_line_16 = PolynomialFeatures(degree=16, include_bias=False).fit_transform(x3_line)
y3_line_16 = model_3.predict(x3_line_16)

plt.plot(x3_line, y3_line_16)
plt.plot(x3 , y3, 'mo')

score3_16 = model_3.score(x3_16 , y3)
print(score3_16)
# Out:
# 0.9680278076057751

# %%
x4 = np.random.rand(1000) * 30
y4 = 2.358 * x4 -3.121
y4 = y4 + np.random.normal( scale = 10 , size = y4.shape)
x4 = x4.reshape(-1, 1)
y4 = y4.reshape (-1 , 1)
#plt.plot(x4, y4, 'go')

# %%
model_4 = LinearRegression(normalize=True).fit(x4 , y4)

x4_line = np.arange(-5, 35, 0.01).reshape(-1 , 1)
y4_line = model_4.predict(x4_line)

plt.plot(x4 , y4 , 'go')
plt.plot(x4_line , y4_line )

score4_1 = model_4.score (x4 , y4)
print(score4_1)
# Out:
# 0.791314630461295

# %%
poly4 = PolynomialFeatures(degree=4, include_bias=False)
x4_4 = poly4.fit_transform(x4)

poly4 = PolynomialFeatures(degree=16, include_bias=False)
x4_16 = poly4.fit_transform(x4)

# %%
model_4= LinearRegression(normalize=True).fit(x4_4, y4)

x4_line = np.arange(-5, 35, 0.1).reshape(-1 , 1)
x4_line_4 = PolynomialFeatures(degree=4, include_bias=False).fit_transform(x4_line)
y4_line_4 = model_4.predict(x4_line_4)

plt.plot(x4, y4, 'go')
plt.plot(x4_line , y4_line_4)

score4_4 = model_4.score(x4_4 , y4)
print(score4_4)
# Out:
# 0.7915936443285734

# %%
model_4= LinearRegression(normalize=True).fit(x4_16, y4)

x4_line = np.arange(0, 31, 0.01).reshape(-1 , 1)
x4_line_16 = PolynomialFeatures(degree=16, include_bias=False).fit_transform(x4_line)
y4_line_16 = model_4.predict(x4_line_16)

plt.plot(x4, y4, 'go')
plt.plot(x4_line, y4_line_16)

score4_16 = model_4.score(x4_16 , y4)
print(score4_16)
# Out:
# 0.7944361954259775

# %%
#Final accuracy 
model = LinearRegression(normalize=True)
x1_1 = np.array([5 , 25, 100, 1000]).reshape(-1, 1)
y1_1= np.array([score1_1 , score2_1, score3_1, score4_1]). reshape (-1 , 1)
model.fit(x1_1 , y1_1)

model_4 = LinearRegression(normalize=True)
x2_4 = np.array([5 , 25, 100, 1000]).reshape(-1, 1)
y2_4= np.array([score1_4 , score2_4, score3_4, score4_4]). reshape (-1 , 1)
model_4.fit(x2_4, y2_4)

model_16 = LinearRegression(normalize=True)
x3_16 = np.array([5 , 25, 100, 1000]).reshape(-1, 1)
y3_16= np.array([score1_16 , score2_16, score3_16, score4_16]). reshape (-1 , 1)
model_16.fit(x3_16 , y3_16)
# Out:
# LinearRegression(normalize=True)

# %%
xline = np.arange(0, 1000 , 0.1).reshape(-1, 1)
yline = model.predict(xline)
plt.plot(xline , yline , 'y--' , label ='Pow 1')
plt.xlabel('Datas')
plt.ylabel('Final accuracy')
plt.legend()

# %%
xline2 = np.arange(0, 1000 , 0.1).reshape(-1, 1)
xline2_4 = PolynomialFeatures(4, include_bias=False).fit_transform(xline2) 
yline2_4 = model_4.predict(xline2)
plt.plot(xline2 , yline2_4 , 'c--', label= 'Pow 4')
plt.xlabel('Datas')
plt.ylabel('Final accuracy')
plt.legend()

# %%
xline3 = np.arange(0, 1000 , 0.1).reshape(-1, 1)
xline3_16 = PolynomialFeatures(16, include_bias=False).fit_transform(xline3) 
yline_4 = model_4.predict(xline3)
plt.plot(xline2 , yline2_4 , 'm--', label= 'Pow 16')
plt.xlabel('Datas')
plt.ylabel('Final accuracy')
plt.legend()
